# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

pd.set_option('display.max_columns', None) # Todas as colunas
pd.set_option('display.max_rows', None) # Todas as linhas
pd.options.display.float_format = '{:.2f}'.format

# %%
# Carregando o arquivo CSV

df_original = pd.read_csv('/Users/ryan.oliveira/Desktop/puc/ppl-cd-pcd-sist-int-2025-1-grupo-5-2025-1/assets/data/State_of_data_BR_2023_Kaggle - df_survey_2023.csv') #Dataframe

# %%
# Verificando as colunas e primeiras linhas
df_original.head()
# Out:
#                        ('P0', 'id')  ('P1_a ', 'Idade')  \
# 0  001b2d1qtli8t9z7oqgdhj001b2d4i0g                  31
# 1  0026aa3fwd78u0026asg7456tfkjg2cs                  30
# 2  00r21rb9pusd1b0v7ew00r21rw3dy69w                  37
# 3  00urm3jf2cek12w6ygue00urm3jzd17j                  22
# 4  00v0az4g792svil00vn6y1kfm9hq8vy9                  34
#
#   ('P1_a_1 ', 'Faixa idade') ('P1_b ', 'Genero') ('P1_c ', 'Cor/raca/etnia')  \
# 0                      30-34           Masculino                      Branca
# 1                      30-34           Masculino                      Branca
# 2                      35-39            Feminino                     Amarela
# 3                      22-24           Masculino                       Preta
# 4                      30-34           Masculino                      Branca
#
#   ('P1_d ', 'PCD')  ('P1_e ', 'experiencia_profissional_prejudicada')  \
# 0              Não                                                NaN
# ...

# %%
# Verificando as dimensões do CSV. 
df_original.shape
# Out:
# (5293, 399)

# %%
# Verificando informações do arquivo
df_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5293 entries, 0 to 5292
# Columns: 399 entries, ('P0', 'id') to ('P8_d_12 ', 'Treinando e aplicando LLM's para solucionar problemas de negócio.')
# dtypes: float64(328), int64(2), object(69)
# memory usage: 16.1+ MB

# %%
# Todas as colunas com seus tipos de dados correspondente
print(df_original.dtypes)
# Out:
# ('P0', 'id')                                                                                                                                                                                                     object
# ('P1_a ', 'Idade')                                                                                                                                                                                                int64
# ('P1_a_1 ', 'Faixa idade')                                                                                                                                                                                       object
# ('P1_b ', 'Genero')                                                                                                                                                                                              object
# ...

# %%
colunas_interesse_uf = [
    "('P1_i ', 'Estado onde mora')",
    "('P1_i_1 ', 'uf onde mora')",
    "('P1_i_2 ', 'Regiao onde mora')"
]
try:
    nulos_uf = df_original[colunas_interesse_uf].isnull().sum()
    print(nulos_uf)
except KeyError as e:
    print(f"Erro: {e}")
# Out:
# ('P1_i ', 'Estado onde mora')      121
# ('P1_i_1 ', 'uf onde mora')        124
# ('P1_i_2 ', 'Regiao onde mora')    124
# dtype: int64
